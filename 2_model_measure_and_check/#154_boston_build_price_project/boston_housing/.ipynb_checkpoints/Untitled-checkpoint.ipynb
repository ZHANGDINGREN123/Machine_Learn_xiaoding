# %%
# Import libraries necessary for this project
import numpy as np
import pandas as pd
from sklearn.cross_validation import ShuffleSplit

# Import supplementary visualizations code visuals.py
import visuals as vs

# Pretty display for notebooks
# %matplotlib inline

# Load the Boston housing dataset
data = pd.read_csv('housing.csv')
prices = data['MEDV']
features = data.drop('MEDV', axis = 1)
    
# Success
# print "Boston housing dataset has {} data points with {} variables each.".format(*data.shape)
print features
# Out:
#         RM  LSTAT  PTRATIO
# 0    6.575   4.98     15.3
# 1    6.421   9.14     17.8
# 2    7.185   4.03     17.8
# 3    6.998   2.94     18.7
# 4    7.147   5.33     18.7
# 5    6.430   5.21     18.7
# 6    6.012  12.43     15.2
# 7    6.172  19.15     15.2
# 8    5.631  29.93     15.2
# 9    6.004  17.10     15.2
# 10   6.377  20.45     15.2
# 11   6.009  13.27     15.2
# 12   5.889  15.71     15.2
# 13   5.949   8.26     21.0
# 14   6.096  10.26     21.0
# 15   5.834   8.47     21.0
# 16   5.935   6.58     21.0
# 17   5.990  14.67     21.0
# 18   5.456  11.69     21.0
# 19   5.727  11.28     21.0
# 20   5.570  21.02     21.0
# 21   5.965  13.83     21.0
# 22   6.142  18.72     21.0
# 23   5.813  19.88     21.0
# 24   5.924  16.30     21.0
# 25   5.599  16.51     21.0
# 26   5.813  14.81     21.0
# 27   6.047  17.28     21.0
# 28   6.495  12.80     21.0
# 29   6.674  11.98     21.0
# ..     ...    ...      ...
# 459  6.484  18.68     20.2
# 460  5.304  24.91     20.2
# 461  6.185  18.03     20.2
# 462  6.229  13.11     20.2
# 463  6.242  10.74     20.2
# 464  6.750   7.74     20.2
# 465  7.061   7.01     20.2
# 466  5.762  10.42     20.2
# 467  5.871  13.34     20.2
# 468  6.312  10.58     20.2
# 469  6.114  14.98     20.2
# 470  5.905  11.45     20.2
# 471  5.454  18.06     20.1
# 472  5.414  23.97     20.1
# 473  5.093  29.68     20.1
# 474  5.983  18.07     20.1
# 475  5.983  13.35     20.1
# 476  5.707  12.01     19.2
# 477  5.926  13.59     19.2
# 478  5.670  17.60     19.2
# 479  5.390  21.14     19.2
# 480  5.794  14.10     19.2
# 481  6.019  12.92     19.2
# 482  5.569  15.10     19.2
# 483  6.027  14.33     19.2
# 484  6.593   9.67     21.0
# 485  6.120   9.08     21.0
# 486  6.976   5.64     21.0
# 487  6.794   6.48     21.0
# 488  6.030   7.88     21.0
#
# [489 rows x 3 columns]

# %%
price = np.array([prices])
# TODO: Minimum price of the data
minimum_price = np.min(price)

# TODO: Maximum price of the data
maximum_price = np.max(price)

# TODO: Mean price of the data
mean_price = np.mean(price)

# TODO: Median price of the data
median_price = np.median(price)

# TODO: Standard deviation of prices of the data
std_price = np.std(price)

# Show the calculated statistics
print "Statistics for Boston housing dataset:\n"
print "Minimum price: ${:,.2f}".format(minimum_price)
print "Maximum price: ${:,.2f}".format(maximum_price)
print "Mean price: ${:,.2f}".format(mean_price)
print "Median price ${:,.2f}".format(median_price)
print "Standard deviation of prices: ${:,.2f}".format(std_price)
# Out:
# Statistics for Boston housing dataset:
#
# Minimum price: $105,000.00
# Maximum price: $1,024,800.00
# Mean price: $454,342.94
# Median price $438,900.00
# Standard deviation of prices: $165,171.13

# %%
# TODO: Import 'r2_score'
from sklearn.metrics import r2_score

def performance_metric(y_true, y_predict):
    """ Calculates and returns the performance score between 
        true and predicted values based on the metric chosen. """  
    # TODO: Calculate the performance score between 'y_true' and 'y_predict'
    score = r2_score(y_true, y_predict) 
    # Return the score
    return score

score = performance_metric([3, -0.5, 2, 7, 4.2], [2.5, 0.0, 2.1, 7.8, 5.3])
print "Model has a coefficient of determination, R^2, of {:.3f}.".format(score)
# Out:
# Model has a coefficient of determination, R^2, of 0.923.

# %%
# TODO: Import 'train_test_split'
from sklearn.model_selection import train_test_split


X = features
y = prices
print X.shape, y.shape
# print X, y


# TODO: Shuffle and split the data into training and testing subsets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2,random_state = 55)

# Success
print X_train.shape,X_test.shape,y_train.shape,y_test.shape
print "Training and testing split was successful."
# Out:
# (489, 3) (489,)
# (391, 3) (98, 3) (391,) (98,)
# Training and testing split was successful.

# %%
# Produce learning curves for varying training set sizes and maximum depths
vs.ModelLearning(features, prices)
# Out:
# [ 0.          0.05707304  0.02862674  0.02844559  0.03043416  0.02301939
#   0.02021814  0.01731828  0.01060626] [ 1.          0.56100364  0.51004554  0.51260482  0.48956553  0.47674092
#   0.46044016  0.45939529  0.45634148] [ 0.33223129  0.09021907  0.10596607  0.09931458  0.08189891  0.08305863
#   0.05850562  0.05281976  0.04101571] [-0.20009584  0.37449712  0.40065884  0.40445278  0.41966023  0.39745028
#   0.41795627  0.39563803  0.39604441]
# [ 0.          0.03478141  0.02188703  0.01657103  0.01501328  0.01688781
#   0.01238512  0.00989494  0.01018928] [ 1.          0.89965647  0.87144616  0.85978011  0.84103005  0.83542747
#   0.82722384  0.82128451  0.8247727 ] [ 0.33223129  0.06883649  0.07683992  0.05436954  0.059277    0.05594663
#   0.03741641  0.03202484  0.03487537] [-0.20009584  0.63714714  0.70983816  0.73249514  0.75516772  0.74808639
#   0.77197493  0.77076083  0.76349216]
# [ 0.          0.00712797  0.01217744  0.00379651  0.00796149  0.00644105
#   0.00531845  0.00587492  0.0076178 ] [ 1.          0.98994818  0.97281963  0.95812835  0.94770805  0.93696495
#   0.92994523  0.92564157  0.92325587] [ 0.33223129  0.10690977  0.07245578  0.06984253  0.05770733  0.05962724
#   0.04659806  0.05260053  0.0606352 ] [-0.20009584  0.58626954  0.66805352  0.71680856  0.74721897  0.74928799
#   0.75287688  0.75795289  0.74103449]
# [  0.00000000e+00   6.33229017e-05   1.48932725e-03   2.08854233e-03
#    2.43793905e-03   4.15792506e-03   3.85231866e-03   4.16858190e-03
#    5.00081908e-03] [ 1.          0.99996588  0.99878618  0.99639939  0.99294404  0.99159624
#   0.98764821  0.98417989  0.97996113] [ 0.33223129  0.10618905  0.08539315  0.05439393  0.05380301  0.06618185
#   0.04259059  0.07164163  0.07034128] [-0.20009584  0.58376541  0.64464522  0.69102568  0.70126352  0.70633533
#   0.70456256  0.6836244   0.67372383]

# %%
vs.ModelComplexity(X_train, y_train)

# %%
 # TODO: Import 'make_scorer', 'DecisionTreeRegressor', and 'GridSearchCV'
from sklearn.metrics import make_scorer
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV

def fit_model(X, y):
    """ Performs grid search over the 'max_depth' parameter for a 
        decision tree regressor trained on the input data [X, y]. """
    
    # Create cross-validation sets from the training data
    # sklearn version 0.18: ShuffleSplit(n_splits=10, test_size=0.1, train_size=None, random_state=None)
    # sklearn versiin 0.17: ShuffleSplit(n, n_iter=10, test_size=0.1, train_size=None, random_state=None)
    cv_sets = ShuffleSplit(X.shape[0], n_iter = 10, test_size = 0.20, random_state = 0)

    # TODO: Create a decision tree regressor object
    regressor = DecisionTreeRegressor(random_state=0)

    # TODO: Create a dictionary for the parameter 'max_depth' with a range from 1 to 10
    params = {"max_depth":list(range(1,11))}

    # TODO: Transform 'performance_metric' into a scoring function using 'make_scorer' 
    scoring_fnc = make_scorer(performance_metric)

    # TODO: Create the grid search cv object --> GridSearchCV()
    # Make sure to include the right parameters in the object:
    # (estimator, param_grid, scoring, cv) which have values 'regressor', 'params', 'scoring_fnc', and 'cv_sets' respectively.
    grid = GridSearchCV(regressor,params,scoring=scoring_fnc,cv=cv_sets)

    # Fit the grid search object to the data to compute the optimal model
    grid = grid.fit(X, y)

    # Return the optimal model after fitting the data
    return grid.best_estimator_

# %%
from sklearn.metrics import fbeta_score,make_scorer
ftwo_scorer = make_scorer(fbeta_score,beta=2)
print ftwo_scorer
print make_scorer(fbeta_score, beta=2)
from sklearn.model_selection import GridSearchCV
from sklearn.svm import LinearSVC
grid = GridSearchCV(LinearSVC(), param_grid={'C':[1, 10]},
                   scoring=ftwo_scorer)
# Out:
# make_scorer(fbeta_score, beta=2)
# make_scorer(fbeta_score, beta=2)

# %%
# Fit the training data to the model using grid search
reg = fit_model(X_train, y_train)

# Produce the value for 'max_depth'
print "Parameter 'max_depth' is {} for the optimal model.".format(reg.get_params()['max_depth'])
print reg.get_params
# Out:
# Parameter 'max_depth' is 4 for the optimal model.
# <bound method DecisionTreeRegressor.get_params of DecisionTreeRegressor(criterion='mse', max_depth=4, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=0, splitter='best')>

# %%
# Produce a matrix for client data
client_data = [[5, 17, 15], # Client 1
               [4, 32, 22], # Client 2
               [8, 3, 12]]  # Client 3

# Show predictions
for i, price in enumerate(reg.predict(client_data)):
    print "Predicted selling price for Client {}'s home: ${:,.2f}".format(i+1, price)
print client_data
# Out:
# Predicted selling price for Client 1's home: $409,350.00
# Predicted selling price for Client 2's home: $227,433.96
# Predicted selling price for Client 3's home: $893,760.00
# [[5, 17, 15], [4, 32, 22], [8, 3, 12]]

# %%
# vs.PredictTrials(features, prices, fit_model, client_data)

# %%
    X = features
    y = prices
    fitter = fit_model
    data = client_data
    # Store the predicted prices
    prices = []

    for k in range(9):
        # Split the data
        X_train, X_test, y_train, y_test = train_test_split(X, y, \
            test_size = 0.2, random_state = k)
        
        # Fit the data
        reg = fitter(X_train, y_train)
        
        # Make a prediction
        pred = reg.predict([data[0]])[0]
        prices.append(pred)
        # Result
        print "Trial {}: ${:,.2f}".format(k+1, pred)

    # Display price range
    print "\nRange in prices: ${:,.2f}".format(max(prices) - min(prices))
# Out:
# Trial 1: $391,183.33
# Trial 2: $424,935.00
# Trial 3: $415,800.00
# Trial 4: $420,622.22
# Trial 5: $418,377.27
# Trial 6: $411,931.58
# Trial 7: $399,663.16
# Trial 8: $407,232.00
# Trial 9: $351,577.61
#
# Range in prices: $73,357.39
